# %% [markdown]
# # AMD CX Routing Engine Demo
# Run the cell below to install dependencies and start the FastAPI server.

# %%
# !pip install fastapi uvicorn sqlalchemy pydantic python-multipart mcp openai

import subprocess
import time

print('Starting the backend server on port 8000...')
process = subprocess.Popen(['uvicorn', 'backend.main:app', '--host', '0.0.0.0', '--port', '8000'])
time.sleep(2)
print('Server is running! Open http://localhost:8000 in your browser.')

# %% [markdown]
# ### Stop the Server
# Run the cell below when you are done to free up the port.

# %%
process.terminate()
print('Server stopped.')
